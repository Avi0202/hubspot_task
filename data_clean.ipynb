# %%
import pandas as pd


df=pd.read_csv('Orders_Master.csv')
df.head()
# Out:
#   order_id                     customer_name                 carrier_name  \
# 0  FSA8811                  Auto Now Wichita              Access Trucking
# 1  FSA8933                             Uhaul   BORDERLINE MOTORSPORTS LLC
# 2  FSA8943                     Franklin CDJR                  XFACTOR LLC
# 3  FSA8956  Carl Black Chevrolet - Nashville  ROYAL FAMILY TRANSPORTATION
# 4  FSA8961                             Uhaul              EZ EXPEDITE INC
#
#    vehicles_count pickup_zip delivery_zip  customer_zip  distance_miles  \
# 0               1      75071        67213       67213.0          351.28
# 1               3       7047        28625       95501.0          601.60
# 2               1      46163        37064       37064.0          314.23
# 3               1      37210        32820       37210.0          700.24
# 4               3      19145        49348       95501.0          716.77
#
#   pickup_date delivery_date  transit_days  order_cost  order_price  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5680 entries, 0 to 5679
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   order_id        5680 non-null   object
#  1   customer_name   5678 non-null   object
#  2   carrier_name    5680 non-null   object
#  3   vehicles_count  5680 non-null   int64
#  4   pickup_zip      5680 non-null   object
#  5   delivery_zip    5680 non-null   object
#  6   customer_zip    3872 non-null   float64
#  7   distance_miles  5680 non-null   float64
#  8   pickup_date     5656 non-null   object
#  9   delivery_date   5643 non-null   object
#  10  transit_days    5637 non-null   float64
#  11  order_cost      5680 non-null   float64
#  12  order_price     5680 non-null   float64
#  13  gross_profit    5680 non-null   float64
#  14  margin_pct      5679 non-null   float64
# dtypes: float64(7), int64(1), object(7)
# memory usage: 665.8+ KB
